# %% [markdown]
# <a href="https://colab.research.google.com/github/meng19951027/Matplotlib-/blob/main/gstools_random_field.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gstools
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gstools
#   Downloading gstools-1.3.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 10.2 MB/s
# Collecting hankel>=1.0.0
#   Downloading hankel-1.2.1-py3-none-any.whl (12 kB)
# Collecting emcee>=3.0.0
#   Downloading emcee-3.1.2-py2.py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 2.4 MB/s
# Collecting pyevtk>=1.1.1
#   Downloading pyevtk-1.5.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from gstools) (1.7.3)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from gstools) (1.21.6)
# Collecting meshio>=4.0.0
#   Downloading meshio-5.3.4-py3-none-any.whl (167 kB)
#      |████████████████████████████████| 167 kB 39.9 MB/s
# Requirement already satisfied: mpmath>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from hankel>=1.0.0->gstools) (1.2.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from meshio>=4.0.0->gstools) (4.12.0)
# Collecting rich
#   Downloading rich-12.5.1-py3-none-any.whl (235 kB)
#      |████████████████████████████████| 235 kB 43.3 MB/s
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->meshio>=4.0.0->gstools) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->meshio>=4.0.0->gstools) (3.8.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from rich->meshio>=4.0.0->gstools) (2.6.1)
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 3.9 MB/s
# Installing collected packages: commonmark, rich, pyevtk, meshio, hankel, emcee, gstools
# Successfully installed commonmark-0.9.1 emcee-3.1.2 gstools-1.3.5 hankel-1.2.1 meshio-5.3.4 pyevtk-1.5.0 rich-12.5.1

# %%
import gstools as gs

# %%
import gstools as gs
x = y = range(100)
model = gs.Gaussian(dim=2, var=1, len_scale=10)
srf = gs.SRF(model, seed=20170519)
field = srf.structured([x, y])
srf.plot()
